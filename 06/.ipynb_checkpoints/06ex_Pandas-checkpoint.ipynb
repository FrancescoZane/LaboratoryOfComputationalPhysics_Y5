# %% [markdown]
# ## Pandas analysis
#
# This exercise consists in analyzing a dataset containg timing information from a series of Time-to-Digital-Converters (TDC) implemented in a couple of FPGAs. <br>
# Each measurement (i.e. each row of the input file) consists of a flag that specifies: <br>
# the type of message ('HEAD', which in this case is always 1), <br>
# two addresses of the TDC providing the signal ('FPGA' and 'TDC_CHANNEL'), <br>
# and the timing information ('ORBIT_CNT', 'BX_COUNTER', and 'TDC_MEAS').<br>
# Each TDC count corresponds to 25/30 ns, whereas a unit of BX_COUNTER corresponds to 25 ns, and the ORBIT_CNT is increased every 'x' BX_COUNTER. This allows to store the time in a similar way to hours, minutes and seconds.

# %%
# If you didn't download it yet, please get the relevant file now!
# !wget https://www.dropbox.com/s/xvjzaxzz3ysphme/data_000637.txt -P ~/data/

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# 1\. Create a Pandas DataFrame reading N rows of the 'data_000637.txt' dataset. Choose N to be smaller than or equal to the maximum number of rows and larger that 10k.

# %%
num_raws = 15000
file_name = "data_000637.txt"
data = pd.read_csv(file_name)
file = data.head(num_raws)
file
# Out:
#        HEAD  FPGA  TDC_CHANNEL   ORBIT_CNT  BX_COUNTER  TDC_MEAS
# 0         1     0          123  3869200167        2374        26
# 1         1     0          124  3869200167        2374        27
# 2         1     0           63  3869200167        2553        28
# 3         1     0           64  3869200167        2558        19
# 4         1     0           64  3869200167        2760        25
# ...     ...   ...          ...         ...         ...       ...
# 14995     1     1            4  3869200316        3399         9
# 14996     1     1           17  3869200316        3400        15
# 14997     1     1           10  3869200316        3530        16
# 14998     1     1            8  3869200316        3533        18
# 14999     1     0          139  3869200316        3539         0
#
# [15000 rows x 6 columns]

# %% [markdown]
# 2\. Find out the number of BX in a ORBIT (the value 'x').

# %%
file.max()
# Out:
# HEAD                    1
# FPGA                    1
# TDC_CHANNEL           139
# ORBIT_CNT      3869200316
# BX_COUNTER           3563
# TDC_MEAS               29
# dtype: int64

# %% [markdown]
# 3\. Find out how much the data taking lasted. You can either make an estimate based on the fraction of the measurements (rows) you read, or perform this check precisely by reading out the whole dataset.

# %% [markdown]
# 4\. Create a new column with the absolute time in ns (as a combination of the other three columns with timing information).

# %%
offset = 27*file.loc[0]['TDC_CHANNEL'] + 25*file.loc[0]['BX_COUNTER'] + file.loc[0]['ORBIT_CNT']*25*27
file['tot_time_ns'] = 27*file['TDC_CHANNEL'] + 25*file['BX_COUNTER'] + file['ORBIT_CNT']*25*27 - offset
file
# Out:
# /tmp/ipykernel_8208/1304624476.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file['tot_time_ns'] = 27*file['TDC_CHANNEL'] + 25*file['BX_COUNTER'] + file['ORBIT_CNT']*25*27 - offset
#        HEAD  FPGA  TDC_CHANNEL   ORBIT_CNT  BX_COUNTER  TDC_MEAS  tot_time_ns
# 0         1     0          123  3869200167        2374        26            0
# 1         1     0          124  3869200167        2374        27           27
# 2         1     0           63  3869200167        2553        28         2855
# 3         1     0           64  3869200167        2558        19         3007
# 4         1     0           64  3869200167        2760        25         8057
# ...     ...   ...          ...         ...         ...       ...          ...
# 14995     1     1            4  3869200316        3399         9       122987
# 14996     1     1           17  3869200316        3400        15       123363
# 14997     1     1           10  3869200316        3530        16       126424
# 14998     1     1            8  3869200316        3533        18       126445
# 14999     1     0          139  3869200316        3539         0       130132
#
# [15000 rows x 7 columns]

# %% [markdown]
# 5\. Replace the values (all 1) of the HEAD column randomly with 0 or 1.

# %%
file['HEAD'] = pd.Series(np.random.choice([0,1], num_raws, p=[0.5, 0.5]))
file
# Out:
# /tmp/ipykernel_8208/3485485624.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file['HEAD'] = pd.Series(np.random.choice([0,1], num_raws, p=[0.5, 0.5]))
#        HEAD  FPGA  TDC_CHANNEL   ORBIT_CNT  BX_COUNTER  TDC_MEAS  tot_time_ns
# 0         1     0          123  3869200167        2374        26            0
# 1         0     0          124  3869200167        2374        27           27
# 2         1     0           63  3869200167        2553        28         2855
# 3         1     0           64  3869200167        2558        19         3007
# 4         1     0           64  3869200167        2760        25         8057
# ...     ...   ...          ...         ...         ...       ...          ...
# 14995     0     1            4  3869200316        3399         9       122987
# 14996     0     1           17  3869200316        3400        15       123363
# 14997     0     1           10  3869200316        3530        16       126424
# 14998     0     1            8  3869200316        3533        18       126445
# 14999     0     0          139  3869200316        3539         0       130132
#
# [15000 rows x 7 columns]

# %% [markdown]
# 6\. Create a new DataFrame that contains only the rows with HEAD=1.

# %%
new_file = file[file['HEAD']==1]
new_file
# Out:
#        HEAD  FPGA  TDC_CHANNEL   ORBIT_CNT  BX_COUNTER  TDC_MEAS  tot_time_ns
# 0         1     0          123  3869200167        2374        26            0
# 2         1     0           63  3869200167        2553        28         2855
# 3         1     0           64  3869200167        2558        19         3007
# 4         1     0           64  3869200167        2760        25         8057
# 6         1     0           61  3869200167        2772        14         8276
# ...     ...   ...          ...         ...         ...       ...          ...
# 14985     1     0          139  3869200316        3389         0       126382
# 14987     1     1            5  3869200316        3390         7       122789
# 14989     1     1          139  3869200316        3398         0       126607
# 14990     1     1           18  3869200316        3387        22       123065
# 14991     1     0           64  3869200316        3387        18       124307
#
# [7530 rows x 7 columns]

# %% [markdown]
# 7\. Make two occupancy plots (one for each FPGA), i.e. plot the number of counts per TDC channel

# %%
# new_file[new_file['FPGA']==0]['TDC_CHANNEL'].plot()
new_file[new_file['FPGA']==1]['TDC_CHANNEL'].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# 8\. Use the groupby method to find out the noisy channels, i.e. the TDC channels with most counts (say the top 3)

# %% [markdown]
# 9\. Count the number of unique orbits. Count the number of unique orbits with at least one measurement from TDC_CHANNEL=139
